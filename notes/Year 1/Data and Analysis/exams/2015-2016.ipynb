# %% [markdown]
# ### Question 1
#
# #### Part A
#
# (i) Key: A field that uniquly identifys an instance of an entity.
#
# (ii) Superkey:
#
# (iii) Composite key: A key made from the combination of two or more fields.
#
# (iv) Primary key: The key used by the database to uniquily identify each entity.
#
# #### Part B
#
# ![exam.png](attachment:exam.png)
#
# #### Part C
#
# (i) Only allows a relation for programming language already defined within the `ProgLang` table, thus avoiding the issue of users entering multiple spellings for the same programming language, for example `JavaScript` and `js`.
#
# (ii)
# ```sql
# CREATE TABLE Endorsement (
#     byUser varchar(254),
#     ofUser varchar(254),
#     forLang varchar(100),
#     PRIMARY KEY (byUser, ofUser, forLang),
#     FOREIGN KEY (byUser) REFERENCES User(email),
#     FOREIGN KEY (ofUser) REFERENCES User(email),
#     FOREIGN KEY (forLang) REFERENCES ProgLang(name)
# )
# ```
#
# (iii)
# $$
# \{ U \; | \; (U \in \text{User}) \; \land \; (E \in \text{Endorsement}) \; \land \; (P \in \text{ProgLang}) \; \land \; (U.email = E.ofUser) \; \land \; (E.forLang = P.name) \; \land \; (P.name = "Haskell") \}
# $$
#
# (iv)
# $$
# \pi_{\text{nickname}}(\sigma_{\text{forLang = C}}(\text{Student} \bowtie_{\text{Student.email = Endorsement.byUser}} \text{Endorsement}))
# $$
#
# (v)
# ```sql
# SELECT UNIQUE User.name, User.email FROM User, Endorsement WHERE
#     User.email = Endorsement.byUser AND
#     Endorsement.byUser = Endorsement.ofUser
# ```

# %% [markdown]
# ### Question 2
#
# #### Part A
#
# #### Part B
# ```dtd
# <!ELEMENT math ( apply | cn | ci ) >
# <!ELEMENT apply ( ( plus | times | power ) ( apply | cn | ci ) ( apply | cn | ci ) ) >
#
# <!ATTLIST ci type (integer, real, complex) #IMPLIED >
# <!ATTLIST cn type (integer, real, complex) #IMPLIED >
# <!ATTLIST cn base=10 #IMPLIED >
# ```
#
# #### Part C
# ```xpath
# //ci[@type="real"]
# ```
#
# #### Part D
# ```xpath
# //ci[@type="complex"]/..
# ```

# %% [markdown]
# ### Question 3
#
# #### Part A
# The proportion of relevant documents from the documents returned.
#
# #### Part B
# Precision, its more important that the most relevant results are returned rather than more results which may not be relevant since their is a large amount of data each query will likely have a large amount of results.
#
# #### Part C
